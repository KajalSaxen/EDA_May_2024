# %% [markdown]
# **Numerical analysis**

# %%
# import pacckages 
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\HP\Documents\nareshIT\EDA\Data file\Visadataset.csv"

# %%
Visa_df=pd.read_csv(path)
Visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %%
Visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied
# 3       83434.0300         Year                  Y      Denied
# 4      149907.3900         Year                  Y   Certified

# %% [markdown]
# **convert numerical and categorical columns**

# %%
cat_columns=Visa_df.select_dtypes(include='object').columns
num_columns=Visa_df.select_dtypes(exclude='object').columns
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# **prevailing_wage**

# %%
Visa_df.loc[:,'prevailing_wage']
Visa_df.iloc[:,[8]]
Visa_df['prevailing_wage']
Visa_df[['prevailing_wage']]
# Out:
#        prevailing_wage
# 0             592.2029
# 1           83425.6500
# 2          122996.8600
# 3           83434.0300
# 4          149907.3900
# ...                ...
# 25475       77092.5700
# 25476      279174.7900
# 25477      146298.8500
# 25478       86154.7700
# 25479       70876.9100
#
# [25480 rows x 1 columns]

# %% [markdown]
# - len
#
# - min
#
# - max
#
# - average(mean)
#
# - standard deviation std
#
# - median
#
# - 25p
#
# - 50p
#
# - 75p

# %%
len(Visa_df['prevailing_wage'])
# Out:
# 25480

# %%
#visa_df.iloc[row,columns]
# start: stop:step

# Visa_df.iloc[3:7,2:5]
# row 3 4 5 6
# col 2 3 4


Visa_df.iloc[3:7,2:5]
# Out:
#   education_of_employee has_job_experience requires_job_training
# 3            Bachelor's                  N                     N
# 4              Master's                  Y                     N
# 5              Master's                  Y                     N
# 6            Bachelor's                  N                     N

# %%
min(Visa_df['prevailing_wage'])
# Out:
# 2.1367

# %%
max(Visa_df['prevailing_wage'])
# Out:
# 319210.27

# %%
count=len(Visa_df['prevailing_wage'])
min_wage=min(Visa_df['prevailing_wage'])
max_wage=max(Visa_df['prevailing_wage'])
print("the number of wage samples are:",count)
print("the minimum wage is:",min_wage)
print("the maximum wage is:",max_wage)
# Out:
# the number of wage samples are: 25480
# the minimum wage is: 2.1367
# the maximum wage is: 319210.27

# %% [markdown]
# **Meam**

# %%
Visa_df[['prevailing_wage']].mean()
# Out:
# prevailing_wage    74455.814592
# dtype: float64

# %%
Visa_df['prevailing_wage'].median()
# Out:
# 70308.20999999999

# %%
mean_wage=round(Visa_df['prevailing_wage'].mean(),2)
median_wage=round(Visa_df['prevailing_wage'].median(),2)
print("the average wage is:",mean_wage)
print("the medium wage is:",median_wage)
# Out:
# the average wage is: 74455.81
# the medium wage is: 70308.21

# %% [markdown]
# - mode is not a suitable metric for numerical analysis
#
# - Diffrence observation can have same value

# %%
np.mean(Visa_df['prevailing_wage'])
# Out:
# 74455.81459209183

# %% [markdown]
# **std**

# %%
std_wage=round(Visa_df['prevailing_wage'].std(),2)
std_wage
# Out:
# 52815.94

# %%
count_wage=len(Visa_df['prevailing_wage'])
min_wage=min(Visa_df['prevailing_wage'])
max_wage=max(Visa_df['prevailing_wage'])
print("the number of wage samples are:",count)
mean_wage=round(Visa_df['prevailing_wage'].mean(),2)
median_wage=round(Visa_df['prevailing_wage'].median(),2)
std_wage=round(Visa_df['prevailing_wage'].std(),2)
# Out:
# the number of wage samples are: 25480

# %%
# step-1:  create: a empty list, keep all the value in a list
# step-2: create a index list=['count','min,'max'
# step-3: create a cols list=['pwage']

# %%
count_wage=len(Visa_df['prevailing_wage'])
min_wage=min(Visa_df['prevailing_wage'])
max_wage=max(Visa_df['prevailing_wage'])
print("the number of wage samples are:",count)
mean_wage=Visa_df['prevailing_wage'].mean(),2
median_wage=round(Visa_df['prevailing_wage'].median(),2)
std_wage=round(Visa_df['prevailing_wage'].std(),2)
# Out:
# the number of wage samples are: 25480

# %%
values=[count_wage,min_wage,max_wage,mean_wage,median_wage,std_wage]
index=['count','min','max','mean','median','std']
cols=['prevailing_wage']
pd.DataFrame(values, index=index,columns=cols)
# Out:
#         prevailing_wage
# count        25480.0000
# min              2.1367
# max         319210.2700
# mean         74455.8100
# median       70308.2100
# std          52815.9400

# %%
Visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %% [markdown]
# **25p-50p-75p**

# %% [markdown]
# **percentitiles**
#
# - in numpy we have percentile
#
# - the method is np.percentile()
#
#     - it takes the two arguments
#
#     - a: array means data
#
#     - q value which percentile data we want, that value values we need to provide
#
#     - if we want 25p value then q-25
#
# **quantile**
#
# - in numpy we have quantile
#
# - the method is np.quntile()
#
# - it takes the two arguments
#
#     - a: array means data
#
#     -  q value which percentile data we want. that value we need to provide
#
#    - if we want 25p value then q=0.25
#
#    - if we want 50p value then q=0.50

# %%
np.percentile(Visa_df['prevailing_wage'],30)
# 0 to 1
# Out:
# 42032.848999999995

# %%
np.quantile(Visa_df['prevailing_wage'],0.25)
#0 t0 1
# Out:
# 34015.479999999996

# %%
wage_25p=round(np.percentile(Visa_df['prevailing_wage'],25),2)
wage_50p=round(np.percentile(Visa_df['prevailing_wage'],50),2)
wage_75p=round(np.percentile(Visa_df['prevailing_wage'],75),2)  
print("25p value is:",wage_25p)
print("50p value is:",wage_50p)
print("75p value is:",wage_75p)
# Out:
# 25p value is: 34015.48
# 50p value is: 70308.21
# 75p value is: 107735.51

# %%
count_wage=len(Visa_df['prevailing_wage'])
min_wage=min(Visa_df['prevailing_wage'])
max_wage=max(Visa_df['prevailing_wage'])
mean_wage=Visa_df['prevailing_wage'].mean(),2
median_wage=round(Visa_df['prevailing_wage'].median(),2)
std_wage=round(Visa_df['prevailing_wage'].std(),2)

wage_25p=round(np.percentile(Visa_df['prevailing_wage'],25),2)
wage_50p=round(np.percentile(Visa_df['prevailing_wage'],50),2)
wage_75p=round(np.percentile(Visa_df['prevailing_wage'],75),2) 
values=[count_wage,min_wage,max_wage,
        mean_wage,median_wage,std_wage,wage_25p,wage_50p,wage_75p]
index=['count','min','max','mean','median','std','25p','50p','75p']
cols=['prevailing_wage']
wage_df=pd.DataFrame(values,index,columns=cols)
wage_df
# Out:
#                prevailing_wage
# count                    25480
# min                     2.1367
# max                  319210.27
# mean    (74455.81459209183, 2)
# median                70308.21
# std                   52815.94
# 25p                   34015.48
# 50p                   70308.21
# 75p                  107735.51

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\HP\Documents\nareshIT\EDA\Data file\Visadataset.csv"

# %%
Visa_df=pd.read_csv(path)
Visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %%
cat_columns=Visa_df.select_dtypes(include='object').columns
num_columns=Visa_df.select_dtypes(exclude='object').columns
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
df1=pd.DataFrame()
for i in num_columns:
    count = len(Visa_df[i])
    Min=min(Visa_df[i])
    Max=max(Visa_df[i])
    Mean=Visa_df[i].mean(),2
    Median=round(Visa_df[i].median(),2)
    Std=round(Visa_df[i].std(),2)
    p_25=round(np.percentile(Visa_df[i],25),2)
    p_50=round(np.percentile(Visa_df[i],50),2)
    p_75=round(np.percentile(Visa_df[i],75),2) 
    value=[count,Min,Max,Mean,Median,Std,p_25,p_50,p_75]
    index=['count','min','max','mean','median','std','25','50','75']
    cols=[i]
    df2= pd.DataFrame(value,index=index,columns=cols)
    df1=pd.concat([df1,df2],axis=1)
df1
# Out:
#                no_of_employees             yr_of_estab         prevailing_wage
# count                    25480                   25480                   25480
# min                        -26                    1800                  2.1367
# max                     602069                    2016               319210.27
# mean    (5667.043210361067, 2)  (1979.409929356358, 2)  (74455.81459209183, 2)
# median                  2109.0                  1997.0                70308.21
# std                   22877.93                   42.37                52815.94
# 25                      1022.0                  1976.0                34015.48
# 50                      2109.0                  1997.0                70308.21
# 75                      3504.0                  2005.0               107735.51

# %%
df1

# %% [markdown]
# **percentiles**
#
# - 25p:
#
#   - Assume that 25p values = x
#
#   - 25percentage of data less than valus: x
#
# - for example prevailing_wage 25p value is: 34015.47
#
# - 25 percnetage of people having salary less than 34015.47
#
# - Total numbers: 254800
#
# - 25percentage of 25480=6370
#
# - which means 6370 people has salary less than 34015.7

# %%
np.percentile(Visa_df['prevailing_wage'],25)
# Out:
# 34015.479999999996

# %%
np.percentile(Visa_df['prevailing_wage'],25)
# Out:
# 34015.479999999996

# %%
25*25480/100
# Out:
# 6370.0

# %%
# read the data 
# providing the condition 
#prevailing  wage<percentile value

# %%
wage_data=Visa_df['prevailing_wage']
p_25=np.percentile(Visa_df['prevailing_wage'],25)
wage_data<p_25
con=wage_data<p_25
len(Visa_df[con])
# Out:
# 6370

# %%
wage_data=Visa_df['prevailing_wage']
p_50=np.percentile(Visa_df['prevailing_wage'],25)
wage_data<p_25
con=wage_data<p_25
Visa_df[con]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# 16        EZYV17         Europe              Master's                  Y
# 17        EZYV18           Asia              Master's                  Y
# ...          ...            ...                   ...                ...
# 25461  EZYV25462           Asia              Master's                  Y
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 7                         N             3035         1924
# 12                        N           123876         1963
# 16                        N            76638         1991
# 17                        N             2747         2001
# ...                     ...              ...          ...
# 25461                     N             2861         2004
# 25465                     N             2577         1995
# 25466                     N             1938         2005
# 25470                     N             2272         1970
# 25473                     N             2421         2007
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 7                     West         418.2298         Hour                  Y
# 12               Northeast       28663.0500         Year                  Y
# 16                 Midwest        3706.7900         Year                  Y
# 17                    West       16132.6100         Year                  Y
# ...                    ...              ...          ...                ...
# 25461                 West          54.9196         Hour                  Y
# 25465                South         481.2238         Hour                  Y
# 25466                 West        6973.4000         Year                  Y
# 25470            Northeast         516.4101         Hour                  Y
# 25473            Northeast       22845.5600         Year                  Y
#
#       case_status
# 0          Denied
# 7          Denied
# 12      Certified
# 16      Certified
# 17      Certified
# ...           ...
# 25461      Denied
# 25465   Certified
# 25466      Denied
# 25470   Certified
# 25473   Certified
#
# [6370 rows x 12 columns]

# %%
wage_data=Visa_df['prevailing_wage']
p_50=np.percentile(Visa_df['prevailing_wage'],50)
wage_data<p_50
con=wage_data<p_50
len(Visa_df[con])
# Out:
# 12740

# %%
wage_data=Visa_df['prevailing_wage']
p_75=np.percentile(Visa_df['prevailing_wage'],75)
wage_data<p_75
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4        False
#          ...
# 25475     True
# 25476    False
# 25477    False
# 25478     True
# 25479     True
# Name: prevailing_wage, Length: 25480, dtype: bool

# %%
wage_data=Visa_df['prevailing_wage']
p_75=np.percentile(Visa_df['prevailing_wage'],75)
con=wage_data<p_75
len(Visa_df[con])
# Out:
# 19110

# %%
percentiles

50p:

Assume that 50p values = x

50percentage of data less than valus: x

for example prevailing_wage 50p value is: 12740 

50percnetage of people having salary less than 12740 

Total numbers: 254800

50percentage of 25480=6370

which means 6370 people has salary less than 12740

# %% [markdown]
# **Emperical rule**

# %% [markdown]
# **68-95-99.7 know as E**
# mean-1*std to mean+1std:68%
#
# mean-2*std to mean+2std:95%
#
# mean-3*std to mean+3rd: 99.7%

# %%
# step-1: calculate the mean of prevailing wage

# step-2: calculate the std of prevailing wage

# step-3: Lb =mean-1*std

# step-4:ub=mean+1*std

# step-5:con1=data<Ub

# step-6:con2=data<Lb

# step-7:con3=con1 and con2

# step-8: data[con3]

# step-9: compare with 68% 25480 count

# %%
mu=Visa_df['prevailing_wage'].mean()
sigma=Visa_df['prevailing_wage'].std()
lb=mu-1*sigma
ub=mu+1*sigma
con1=Visa_df['prevailing_wage']<ub
con2=Visa_df['prevailing_wage']>lb
con3=con1&con2
Visa_df[con3]
print(len(Visa_df[con3]))
print(68*len(Visa_df)/100)
# Out:
# 17171
# 17326.4

# %%
mu=Visa_df['prevailing_wage'].mean()
sigma=Visa_df['prevailing_wage'].std()
lb=mu-2*sigma
ub=mu+2*sigma
con1=Visa_df['prevailing_wage']<ub
con2=Visa_df['prevailing_wage']>lb
con3=con1&con2
print(len(Visa_df[con3]))
print(95*len(Visa_df)/100)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25474                     N             2594         1979
# 25475                     Y             2601         2008
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25474            Northeast       51104.7800         Year                  Y
# 25475                South       77092.5700         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25474   Certified
# 25475   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [24582 rows x 12 columns]

# %%
mu=Visa_df['prevailing_wage'].mean()
sigma=Visa_df['prevailing_wage'].std()
lb=mu-3*sigma
ub=mu+3*sigma
con1=Visa_df['prevailing_wage']<ub
con2=Visa_df['prevailing_wage']>lb
con3=con1&con2
Visa_df[con3]
print(len(Visa_df[con3]))
print(97*len(Visa_df)/100)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25474                     N             2594         1979
# 25475                     Y             2601         2008
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25474            Northeast       51104.7800         Year                  Y
# 25475                South       77092.5700         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25474   Certified
# 25475   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25186 rows x 12 columns]

# %%
# import pacckages 
# read the data 
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\HP\Documents\nareshIT\EDA\Data file\Visadataset.csv"

# %%
Visa_df=pd.read_csv(path)
Visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %%
cat_columns=Visa_df.select_dtypes(include='object').columns
num_columns=Visa_df.select_dtypes(exclude='object').columns
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
Visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %% [markdown]
# **histogram**

# %% [markdown]
# - by applying imperical rule we observed slight deviation in the count of data
#
# - Also Mean is slightly deviation from median
#
# - this gives an indication that data does not follows normal distribution
#
# - to understand more clerarly will visulaize the data
#
# - its is numerical data, so the plot name is: **Histogram**
#
# - the plot is avialable in matplotlib
#
# - the method name is hist

# %%
# step-1: read the prevailing wage 

# step-2: plt.hist()

wage_data=Visa_df['prevailing_wage']
plt.hist(wage_data,bins=20)
# Out:
# (array([3863., 2175., 2676., 2828., 2889., 2792., 2485., 2066., 1452.,
#          882.,  408.,  216.,  206.,  167.,  129.,  111.,   66.,   48.,
#           10.,   11.]),
#  array([2.13670000e+00, 1.59625434e+04, 3.19229500e+04, 4.78833567e+04,
#         6.38437634e+04, 7.98041700e+04, 9.57645767e+04, 1.11724983e+05,
#         1.27685390e+05, 1.43645797e+05, 1.59606203e+05, 1.75566610e+05,
#         1.91527017e+05, 2.07487423e+05, 2.23447830e+05, 2.39408237e+05,
#         2.55368643e+05, 2.71329050e+05, 2.87289457e+05, 3.03249863e+05,
#         3.19210270e+05]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# - Histogram will return 3 values
#
#   - Interval count array
#
#   - we have 20 intervals , so we have 20 interval counts
#
# - bins
#
#    - bins means number of intervals
#
#    - we have 20 intervals so we need 21 values
#
#    - will display how many intervals are available
#
# - for example in the bins array the first two
#
# - 2.136 to 15962.543 the count is 3863
#
# - 3863 observation are available between 2.136 to 15962.543
#
# - similarly 2175 observation are avialable between (15962.5434,31922.95)

# %%
1.59625434e+04
# Out:
# 15962.5434

# %%
1.59625434e+04, 3.19229500e+04
# Out:
# (15962.5434, 31922.95)

# %%
wage_data=Visa_df['prevailing_wage']
count,bins,x=plt.hist(wage_data,bins=20)
print(len(count))
print(len(bins))
print(x)
# Out:
# 20
# 21
# <BarContainer object of 20 artists>

# %% [markdown]
# # verify below two statements
# - 3863 observation are available between 2.136 to 15962.543
# - similarly 2175 observation are available between (15962.5434,31922.95)

# %%
lb=2.13670000e+00
ub= 1.59625434e+04
con1=Visa_df['prevailing_wage']<=ub
con2=Visa_df['prevailing_wage']>=lb
con3=con1&con2
print(len(Visa_df[con3]))
# Out:
# 3863

# %%
lb=1.59625434e+04
ub= 3.19229500e+04
con1=Visa_df['prevailing_wage']<=ub
con2=Visa_df['prevailing_wage']>=lb
con3=con1&con2
print(len(Visa_df[con3]))
# Out:
# 2175

# %%
count
# Out:
# array([3863., 2175., 2676., 2828., 2889., 2792., 2485., 2066., 1452.,
#         882.,  408.,  216.,  206.,  167.,  129.,  111.,   66.,   48.,
#          10.,   11.])

# %%
bins
# Out:
# array([2.13670000e+00, 1.59625434e+04, 3.19229500e+04, 4.78833567e+04,
#        6.38437634e+04, 7.98041700e+04, 9.57645767e+04, 1.11724983e+05,
#        1.27685390e+05, 1.43645797e+05, 1.59606203e+05, 1.75566610e+05,
#        1.91527017e+05, 2.07487423e+05, 2.23447830e+05, 2.39408237e+05,
#        2.55368643e+05, 2.71329050e+05, 2.87289457e+05, 3.03249863e+05,
#        3.19210270e+05])

# %%
# import pacckages 
# read the data
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\HP\Documents\nareshIT\EDA\Data file\Visadataset.csv"

# %%
Visa_df=pd.read_csv(path)
Visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %%
cat_columns=Visa_df.select_dtypes(include='object').columns
num_columns=Visa_df.select_dtypes(exclude='object').columns
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
** Drow the histogram using seaborn try tha

# %%
# import pacckages 
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\HP\Documents\nareshIT\EDA\Data file\Visadataset.csv"
